# %% [markdown]
# ### Q1 : What are the benefits of including roles in the programmes?

# %% [markdown]
# ##### Including roles in programme can make it possible to recall any part of the program again and again as per assigned role. Roles can be assigned through defining functions, such that each function can be defined to do a particular role in a programme. This can help in the reusability of a code.

# %% [markdown]
# ### Q2. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# ##### A code inside a function runs, when the function is called in a program.

# %% [markdown]
# ### Q3. What statement causes a feature to be created?

# %% [markdown]
# ##### Simple statement causes a feature to be created

# %% [markdown]
# ### Q4. What is the distinction between a function and a call to a function?

# %% [markdown]
# ##### A function is lines of code to get a result but function call is a process of letting this code to execute

# %% [markdown]
# ### Q5. In a Python application, how many global scopes are there? How many local scopes are there?

# %% [markdown]
# ##### There is only one global scope for a programme and there can be any number of local scope with in a function.

# %% [markdown]
# ### Q6. When a function call returns, what happens to variables in the local scope?

# %% [markdown]
# ##### After function call returns, variable in the local scope will retain its value.

# %% [markdown]
# ### Q7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# ##### A return value returns output of a function. No, it is not possible to have a return value in an expression.

# %% [markdown]
# ### Q8. What is the return value of a call to a function that does not have a return statement?

# %% [markdown]
# ##### There won't be any value displayed as output

# %% [markdown]
# ### Q9. How do you make a function variable refer to the global variable?

# %% [markdown]
# ##### For that you need to use keyword global and define which variable to be referred to global variable.

# %% [markdown]
# ### Q10. What data form does None belong to?

# %% [markdown]
# ##### It belongs to Nonetype.

# %% [markdown]
# ### Q11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# ##### There is no module named areallyourpetsnamederic.

# %% [markdown]
# ### Q12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# ##### After importing spam module, you can call it by spam.bacon()

# %% [markdown]
# ### Q13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# ##### We can use exception handling such as try except to display the error instead of programme crash.

# %% [markdown]
# ### Q14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# ##### Try clause just execute the code written under it and except clause helps to handle the error by printing any error messages as user defines.
